# %%
"""
'Blindness' by Thaly Ramirez.
It was made in January 2023 for a python class.

The story is based in the novel Blindness by Jose Saramago. The player doesn't
need specific knowledge. On the contrary, the game set the player as
some characters' conscience and propose several dilemmas.
Keys to detect possible failure scenarios are given. The game is divided into two
missions: the first one contains three mandatory stages that decides some
resources availability in the second mission. The second mission is a one-stage
situation that determines the efficiency of the player in solving the situation.


Known bugs: 0
"""

#Importing exit fuction to end the game.
from sys import exit

#Defining start of the game
def start():    
    #Introducing the game. Describing the situation and game instructions
    print("""
    A rare blindness condition starts to affect people in the city,
    and you are the only one who knows its high contagion rate.
    
    𝗙𝗜𝗥𝗦𝗧 𝗠𝗜𝗦𝗦𝗜𝗢𝗡
    Boost a cure that avoids the city to fall into chaos.
         """)
    input("<Press enter to continue>\n")
    print("""
    To do so, you must minimize the contagion by leading infected
    people to be isolated. The cure effectiveness will be higher depending in
    how wise you are to choose the best path.
         """)
    input("<Press enter to continue>\n")
    
    #Answering if the user wants to play after reading the instructions
    #Creating a loop to control input errors. 
    while True:
        decision_play=input(prompt=f"""         
    You will be leading the decisions of two main characters in this story.
    Are you ready for it? Yes|No
         """).lower()
    
        if decision_play=="no":
            #Ending game
            print("Ok. Then, see you next time!")
            exit(0)
            break
        elif decision_play=="yes":
            #Start of the story
            print("""
    ¡piiii!, ¡piiii!
                 
    ¡piiii!, ¡piiii!
                              
    A red car stalls the traffic light for the second time in a row.
                 """)
            input("<Press enter to continue>\n")
            print("""
    A man approaches the car and the driver, an old man, argues that
    he has gone blind: a white blindness. The man offers to give him a ride
    home, to which the old man accepts.
                 """)
            input("<Press enter to continue>\n")
            doctor_path()
            break
        else:
            #Controlling wrong inputs by repeating the question
            print("I didn't catch that...")
            continue
        

#Ending the game if the wrong option is selected. 
def game_over():
    print("Seems like you failed the mission!")
    #Creating a loop to control input errors. 
    while True:
        
    #Giving the option of playing again
        play_again=input(prompt="Do you want to play again? Yes|No").lower()
        if play_again=="yes":
            start()
            break
        elif play_again=="no":
            #Ending completely if user doesn't want to play
            print("Then, see you next time!")
            exit(0)
            break
        else:
            #Controlling wrong inputs by repeating the question
            print("I didn't catch that...")
            continue
        
#Giving the option of playing again after completing the game
def new_play():
    print("Congratulations for completing the game!")
    play_again=input(prompt="Do you want to play again? Yes/No").lower()
    if play_again=="yes":
        #Jumping to the start to explain the game again
        start()
    elif play_again=="no":
        #Ending the game
        print("Then, see you next time!")
        exit(0)
    else:
        #Controlling wrong inputs by repeating the question
        print("I didn't catch that...")
        new_play()

#--------------------------------------- FIRST STAGE -------------------------------
#The user plays the DOCTOR role
def doctor_path():
    #Describing the scenario
    print("""
    Once they arrive, the blind man feels vulnerable and asks
    him to go away, fearing that he is a thief. After chasing him away,
    the man waits for his wife who takes him to the ophthalmologist.  
    """)
    input("<Press enter to continue>\n")
    print("""    
    The doctor agrees to receive the new blind man urgently.
    However, to his surprise and frustration, he finds no logical
    explanation for the blindness.
    """)
          
    #Creating a loop to control input errors. 
    while True:
        #Defining the variable for the cure effectiveness of this path to later calculate the overall
        doctor_path.cure2=0
        scenario2=input(prompt="""
    What do you persuade the doctor to do?
    A) Give a cataract diagnostic to protect his image
    B) Not medicate and tell them he needs to review the case
            with some colleagues
    C)Put the man under observation in the hospital
        """).lower()
        #Two out of three options will lead to the same scenario as part of the stage strategy
        if scenario2=="a":
            print("""
    The married couple go back to their house.
    The next morning, the wife wakes up blind and calls the 911.
            
    They are isolated.
            """)
          #Increasing the cure effectiveness
            doctor_path.cure2+=20
            print("<The cure effectiveness has increased 20%>")
            input("<Press enter to continue>\n")
            doctor_wife()
            break
          
        elif scenario2=="c":
            print("""
    They stay in the hospital were fifty people are infected after
    get in touch with the old man and his wife. Later, those people
    spread the infection across the city.
            """)
            input("<Press enter to continue>\n")
            game_over()
            break
        elif scenario2=="b":
            print("""
    The married couple go back to their house.
    The next morning, the wife wakes up blind
    and calls the 911.
            
    They are isolated.
            """)
            #Here the cure rate is summed 
            doctor_path.cure2+=35
            print("<The cure effectiveness has increased 35%!>")
            input("<Press enter to continue>\n")
            doctor_wife()
            break
        else:
            #Controlling wrong inputs by repeating the question
            print("I didn't get that")
            continue
    
#Last mandatory path of 1st mission. After a valid decision is made, the game rules change
def doctor_wife():
        #Describing the situation
        print(f"""
    {("-")*50}
    Back home, the doctor continues to ponder the subject.
    Sitting among books and papers, he himself loses his vision.
        """)
        
        input("<Press enter to continue>\n")
        print(""" 
    The next day the doctor decides to alert the Ministry of Health about a
    possible epidemic of blindness.

    An ambulance is on the way to pick him up and take him to the to the
    abandoned psychiatric hospital where the Ministry of Health has decided
    to admit the newly sightless.
        """)
        input("<Press enter to continue>\n")
        
        while True:
            #Defining the variable for the cure effectiveness of this path to later calculate the overall
            doctor_wife.cure3=0
            doctor_wife.scenario3=input(prompt="""
    The wife of the doctor, 𝘄𝗵𝗼 𝘄𝗶𝗹𝗹 𝗻𝗲𝘃𝗲𝗿 𝗴𝗲𝘁 𝗶𝗻𝗳𝗲𝗰𝘁𝗲𝗱, is worried about
    him going alone.

    What do you suggest her to do?
    A) Fake blindness to be taken with him to the psychiatric hospital
    B)Let it go alone with the hope that it will all be over soon 
            
            """).lower()
            if doctor_wife.scenario3=="a":
                print("""
    Both are taken to the abandoned psychiatric hospital.
    The first blind man and his wife, the thief, the girl with conjunctivitis, and the boy
    with the squint who was also at the ophthalmology clinic the morning
    before arrive in that same area.
                  """)
                #Here the cure rate is summed 
                doctor_wife.cure3+=25
                print("<The cure effectiveness has increased 25%>")
                
                input("<Press enter to continue>\n")
                asylum()
                break
            elif doctor_wife.scenario3=="b":
                print("""
    His husband is taken to the abandoned psychiatric hospital.
    Three days later, there is a big plot between interns that were
    trying to monopolize the food.

    In the figth, the doctor loses his life.
                  """)
                input("<Press enter to continue>\n")
                print("""
    Although you isolated the infected, the wife condition of
    never getting infected was the key tool for you to save the city with
    the cure.

    She decided to not follow your advice anymore because of his
    husband's death. She is devasted!""")
                input("<Press enter to continue>\n")
                game_over()
                break

            else:
                #Controlling wrong inputs by repeating the question
                print("I didn't get that")
                continue

   
    
#------------------------------------ MISSION 2-----------------------------------------------
#User now gets an specific number of doses that can be distributed to 
#help the wife of the doctor to survive. This is the final goal of the mission
def asylum():
    #Defining cure effectiveness score by summing previous variables.
    cure_effectiveness=doctor_path.cure2+doctor_wife.cure3
    print(f"""
    {("-")*50}
    Congratulations! You have completed the 𝗙𝗜𝗥𝗦𝗧 𝗠𝗜𝗦𝗦𝗜𝗢𝗡.
    The final cure effectiveness is: {cure_effectiveness}%
    """)
    input("<Press enter to continue>\n")
    #Explaining the mission and instructions to the user
    print("""
    𝗙𝗜𝗡𝗔𝗟 𝗠𝗜𝗦𝗦𝗜𝗢𝗡
    The wife of the doctor accepted to follow your advice from now on.
    She is the only one that can see perfectly.
    
    The goal is now 𝘀𝘂𝗿𝘃𝗶𝘃𝗶𝗻𝗴.
    """)
    input("<Press enter to continue>\n")
    print("""
   The filth inside the hospital is increasing. 
    Revealing the integrity of the woman's vision would imply that  her life
    will be in danger because of the constant plots within the interns.
    
    𝗞𝗘𝗬: Protect the wife of the doctor at all cost.
    """)
    input("<Press enter to continue>\n")
    #If the cure effectiveness is equal or less than 50% the user will have imperfect doses
    if cure_effectiveness<=50:
        print(f"""
    {("-")*50}
    You previously minimized the contagion speed successfully.
    However, the effectiveness rate is too low to get ride of the infection
    completely!
    """)
        input("<Press enter to continue>\n")
        print(f"""
    You have received 2 doses of 70% purity, which means an infected will
    be able to distinguish vague figures.
    {("-")*50}""")
        input("<Press enter to continue>\n")
        print("""
    Dealing with the situation inside the quarentine room becomes an
    impossible task for the wowan.
    Hopefully, you can help her by providing a dose of the cure to two infected.          
          """)
            
        while True:
            #Giving the options for the limited doses
            dosis_distribution=input(prompt="""
    These are your options:
    A) The thief and the first old man infected
    B) The doctor and the girl with conjunctivitis
          """).lower()
            if dosis_distribution=="a":
                print("""
    The thief and the first old man infected recover their sight enough
    to recognize each other.
                  
    A fight is starts and alerts the other interns in the room and other
    areas. A group of criminals get to guide themselves to the room, where
    they find out about the woman and the cure.
                  """)
                input("<Press enter to continue>\n")
                print("""
    The criminals try to get the cure from the woman, who can't escape and
    is kidnapped.
                  
    Without more hope, she gives up and rejects following you.
                  """)
                input("<Press enter to continue>\n")
                game_over()
                break
            elif dosis_distribution=="b":
                print("""
    Good job! With the doctor and the girl aid, the group gets control over
    the situation and subjugate the place.
                  
    A week later, the Government develop an ultimate cure that heals
    everyone and marks the end of the epidemic.                
                  """)
                input("<Press enter to continue>\n")
                print("""
    Terrific! Your capacity of dealing with high-level problem situations is
    70%. You can be a good leader in the future...
                """)
                input("<Press enter to continue>\n")
                #Ending game after completing
                new_play()
                break
            else:
                #Controlling wrong inputs by repeating the question
                print("I didn't get that")
                continue
    #If cure effectiveness is 50% or more, the user access to a high-quality but not definitive cure
    else:
        print(f"""
    {("-")*50}
    You previously minimized the contagion speed successfully.
    The effectiveness rate is enough to get ride of the infection
    completely!      
    """)
        input("<Press enter to continue>\n")
        print(f"""
    You have received 1 dosis of 90% purity, which means an infected may
    recover his sight for an indefined period of time
    {("-")*50}""")
        input("<Press enter to continue>\n")
        print("""
    Dealing with the situation inside the quarentine room becomes an
    impossible task for the wowan.
    Hopefully, you can help her by providing the cure to an infected.          
          """)
        input("<Press enter to continue>\n")
        
        while True:
            dosis_distribution=input(prompt="""
    These are your options:
    A) Provide the cure to the Government to improve it and develop a definitive
    one 
    B) Give the cure to the doctor and smooth the living situation with
    his skills and experience.
          """).lower()
            if dosis_distribution=="a":
                print("""
    The Government receives the cure and is able to boost its effectiveness.
                  
    Soon, it is distributed to the people in the mental hospital and everyone
    is free a week later.
                  """)
                input("<Press enter to continue>\n")
                print("""
    You are impressive! Your capacity of dealing with high-level problem situations is
    90%. Are you perhaps a born leader?
                """)
                input("<Press enter to continue>\n")
                new_play()
                break
            elif dosis_distribution=="b":
                print("""
    The woman and the doctor work in handling the issues within
    rooms. However, they failed when the doctor, trying to aid a hurt woman
    reveals his condition and is kidnapped by a group of criminals.
                  
    The next day the cure effects ends and he turns blind again. The criminals
    think he is fooling them and take his life in a fit.                  
                  """)
                input("<Press enter to continue>\n")
                game_over()
                break
            else:
                #Controlling wrong inputs by repeating the question
                print("I didn't get that")
                continue

        

#----------------------------------------- Calling to start the game -------------------------------------------
start()
